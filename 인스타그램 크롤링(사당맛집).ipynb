# %% [markdown]
# # 함수 정의하기

# %% [markdown]
# 인스타그램 검색 결과 URL을 만들어서 접속하기 (insta_searching 함수 만들기)

# %%
#함수 작성
def insta_searching(word):  #word라는 매개변수를 받는 insta_searching 이라는 함수 생성
    url = 'https://www.instagram.com/explore/tags/' + word
    return url

# %%
#셀레니움으로 특정 url에 접속하기
from selenium import webdriver
driver = webdriver.Chrome("C:\\Users\\KIM EUNKI\\anaconda3\\chromedriver.exe")
 #크롬드라이버 실행되게 하기

word = '사당맛집'
url = insta_searching(word) #만들어 놓은 함수 사용
driver.get(url) #get 함수 사용

# %% [markdown]
# 첫번째 게시글 열기 (selet_first 함수 만들기)

# %%
#열린 크롬으로 개발자 도구 활용하여 첫번째 게시물 태그 확인 (<div class="_9AhH0"></div>)
#첫번째 게시물 찾아 클릭 함수 만들기

import time

def select_first(driver):
    first = driver.find_element_by_css_selector('div._9AhH0') #find_element_by_css_selector 함수를 사용해 요소 찾기
    first.click()
    time.sleep(3) #로딩을 위해 3초 대기

# %% [markdown]
# 게시글 정보 가져오기 (get_content 함수 만들기)

# %%
#본문 내용, 작성 일시, 위치 정보 및 해시태그(#) 추출

# %%
import re
instagram_tag_dates = []


def get_content(driver):
    # 1. 현재 페이지의 HTML 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    
    # 2. 본문 내용 가져오기
    try:                                         #여러 태그중 첫번째([0]) 태그를 선택  
        content = soup.select('div.C4VMK > span')[0].text #첫 게시글 본문 내용이 <div class="C4VMK"> 임을 알 수 있다.
                                #태그명이 div, class명이 C4VMK인 태그 아래에 있는 span 태그를 모두 선택.
    except:
        content = ' ' 
        
    # 3. 본문 내용에서 해시태그 가져오기(정규표현식 활용)
    tags = re.findall(r'#[^\s#,\\]+', content) 
        # content 변수의 본문 내용 중 #으로 시작하며, #뒤에 연속된 문자(공백이나 #, \ 기호가 아닌 경우)를 모두 찾아 tags 변수에 저장
    
    # 4. 작성 일자 가져오기
    try:
        date = soup.select('time._1o9PC.Nzb55')[0]['datetime'][:10] #앞에서부터 10자리 글자
    except:
        date = ''

    # 5. 좋아요 수 가져오기
    try:
        like = soup.select('div._vJRqr > span')[0].text
    except:
        like = 0
        
    # 6. 위치 정보 가져오기
    try:
        place = soup.select('JF9hh')[0].text
    except:
        place = ''
    
    # 7. 수집한 정보 저장하기
    data = [content, date, like, place, tags]
    return data

# %% [markdown]
# 다음 게시글 열기 (move_next 함수 만들기)

# %%
def move_next(driver):
    right = driver.find_element_by_css_selector('a._65Bje.coreSpriteRightPaginationArrow') 
    right.click()
    time.sleep(2)

# %% [markdown]
# ☆ 여러 게시글 정보 수집하기 (만든 함수들로 코딩하기)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import re

# 1. 크롬으로 인스타그램 - '사당맛집' 검색
driver = webdriver.Chrome("C:\\Users\\KIM EUNKI\\anaconda3\\chromedriver.exe")
word = '사당맛집'
url = insta_searching(word)
driver.get(url) 
time.sleep(4)

# 2. 로그인 하기
login_section = '//*[@id="react-root"]/section/nav/div[2]/div/div/div[3]/div/span/a[1]/button'
driver.find_element_by_xpath(login_section).click()
time.sleep(3)


elem_login = driver.find_element_by_name("username")
elem_login.clear()
elem_login.send_keys('ekey_11_11')

elem_login = driver.find_element_by_name('password')
elem_login.clear()
elem_login.send_keys('test12345')

time.sleep(1)

xpath = """//*[@id="react-root"]/section/main/div/article/div/div[1]/div/form/div[4]/button"""
driver.find_element_by_xpath(xpath).click()

time.sleep(4)

xpath1 = """//*[@id="react-root"]/section/main/div/div/div/div/button"""
driver.find_element_by_xpath(xpath1).click()
time.sleep(4)

# 3. 검색페이지 접속하기
driver.get(url)
time.sleep(4)

# 4. 첫번째 게시글 열기
select_first(driver)

# 5. 비어있는 변수(results) 만들기
results = []

# 여러 게시물 크롤링하기
target = 100 #크롤링할 게시물 수
for i in range(target):
    data = get_content(driver) #게시물 정보 가져오기
    results.append(data)
    move_next(driver)
    
print(results[:2])
# Out:
# [['#당산오돌한번 꽂힌 이후로 주기적으로 가게 되는 듯 ‼️친구가 알아 온 사당맛집 넘 안땡겨서 🤣😂😅그냥 내가 좋아하는 익숙한 당산오돌로 (이기적😚🥰)친구도 다행히 좋아해땨.. 😍소금에 콕 찍어서 먹는 육즙 가득 꼬들살 🐷🍗💞허버허버 먹다가 입천장 까졌따뤼 흑흑,,⠀#사당맛집 #사당역맛집 #사당고기집 #사당맛집추천', '2020-05-26', 0, '', ['#당산오돌한번', '#사당맛집', '#사당역맛집', '#사당고기집', '#사당맛집추천']], ['사당역 최애 맛집 고을래이베리코흑돼지!.내가 제일 자주가는 이베리코흑돼지맛집!고기집의 기본은 고기의 질이쥬??.한번 먹어본 사람은 절대로 못잊는 고기맛ㅠ사당회식의 TOP! @부장님 오늘은 여기가주세요!!.여친남친이랑 데이트부터, 회식장소, 친구들끼리!꼭가자 두번 가자 세번가자!!...#사당역맛집 #사당맛집 #사당회식장소 #사당고기집 #사당모임 #흑돼지맛집', '2020-06-02', 0, '', ['#사당역맛집', '#사당맛집', '#사당회식장소', '#사당고기집', '#사당모임', '#흑돼지맛집']]]

# %%
#100개를 크롤링 후 출력은 2개만 해보았다.

# %% [markdown]
# 수집한 데이터 엑셀파일로 저장하기

# %%
import pandas as pd

results_df = pd.DataFrame(results)
results_df.columns = ['content', 'data', 'like', 'place', 'tags']
results_df.to_excel("C:\\Users\\KIM EUNKI\\Google 드라이브\\GitHub\\Practice\\Insta_Sadang.xlsx")

# %%
results_df
# Out:
#                                               content        data  like place  \
# 0   #당산오돌한번 꽂힌 이후로 주기적으로 ᄀ...  2020-05-26     0
# 1   사당역 최애 맛집 고을래이베리코흑돼지!.내가 제일 자주가는 이베리코흑돼지맛집!고기집...  2020-06-02     0
# 2   어제 진짜 더웠어요 ㅠ 🤢오늘은 그나마 시원ᄒ...  2020-06-12     0
# 3   ..취향저격 맛집 👊이수에서~ 사당까지!내 이...  2020-06-04     0
# 4   -일하다먹는 앙버떡 꿀맛❤️매장에 여유이...  2020-06-06     0
# ..                                                ...         ...   ...   ...
# 95               #계탄언니 #사당맛집 #사당닭갈비#닭갈비맛집with #와인한잔 👍  2020-06-15     0
# 96  사당역 10번출구에서 1분거리라서 접근성이 좋은#100족발..#사당맛집 #사당역맛집...  2020-06-15     0
# 97  .혼자 다 먹었다시그니처 버거 남바완 메뉴ᄅ...  2020-06-15     0
# 98                                   신이나 신이나 엣헴엣헴 신이나  2020-06-15     0
# 99  신신닭발 신메뉴 출시! 튀김많닭입니다많은이용부탁드립니다~...#신신닭발 #선팔하면맞...  2020-06-15     0
#
#                                                  tags
# 0   [#당산오돌한번, #사당맛집, #사당역마...
# 1     [#사당역맛집, #사당맛집, #사당회식장소, #사당고기집, #사당모임, #흑돼지맛집]
# 2   [#비앤미의원, #턱끝필러, #앞턱필러, #ᄆ...
# 3   [#사당맛집, #사당족발, #사당역맛집, ...
# 4   [#떡, #이수떡집, #정애맛담, #민속떡지...
# ..                                                ...
# 95          [#계탄언니, #사당맛집, #사당닭갈비, #닭갈비맛집with, #와인한잔]
# 96  [#100족발.., #사당맛집, #사당역맛집, #사당술집, #사당역술집, #사당역족...
# 97     [#사당맛집, #릿잇타미, #수제버거, #사당]
# 98                                                 []
# 99  [#신신닭발, #선팔하면맞팔, #사당, #사당역맛집, #사당술집, #사당포차, #사...
#
# [100 rows x 5 columns]

# %% [markdown]
# # 워드클라우드 만들어보기

# %% [markdown]
# 크롤링 결과 중 해시태그 데이터 불러오기

# %%
import pandas as pd
raw_total = pd.read_excel("C:\\Users\\KIM EUNKI\\Google 드라이브\\GitHub\\Practice\\Insta_Sadang.xlsx")
raw_total['tags']
# Out:
# 0     ['#당산오돌한번', '#사당맛집', '#사당...
# 1     ['#사당역맛집', '#사당맛집', '#사당회식장소', '#사당고기집', '#사당모...
# 2     ['#비앤미의원', '#턱끝필러', '#앞턱필ᄅ...
# 3     ['#사당맛집', '#사당족발', '#사당역맛...
# 4     ['#떡', '#이수떡집', '#정애맛담', '#민ᄉ...
#                             ...
# 95    ['#계탄언니', '#사당맛집', '#사당닭갈비', '#닭갈비맛집with', '#와...
# 96    ['#100족발..', '#사당맛집', '#사당역맛집', '#사당술집', '#사당역...
# 97    ['#사당맛집', '#릿잇타미', '#수제버거', '...
# 98                                                   []
# 99    ['#신신닭발', '#선팔하면맞팔', '#사당', '#사당역맛집', '#사당술집',...
# Name: tags, Length: 100, dtype: object

# %%
#해시태그 통합저장
tags_total = []

for tags in raw_total['tags']:
    tags_list = tags[2:-2].split("', '")
    for tag in tags_list:
        tags_total.append(tag)

# %%
tags_total[:10]
# Out:
# ['#당산오돌한번',
#  '#사당맛집',
#  '#사당역맛집',
#  '#사당고기집',
#  '#사당맛집추천',
#  '#사당역맛집',
#  '#사당맛집',
#  '#사당회식장소',
#  '#사당고기집',
#  '#사당모임']

# %%
#빈도수 집계
from collections import Counter
tags_counts = Counter(tags_total)

# %%
tags_counts.most_common(30) #가장 많이 사용된 상위 10개의 해시태그
#사당맛집이라는 해시태그가 가장 많이 사용됨을 알 수 있다.
# Out:
# [('#사당맛집', 46),
#  ('#사당역맛집', 34),
#  ('#이수맛집', 32),
#  ('#이수역맛집', 31),
#  ('#사당술집', 29),
#  ('', 29),
#  ('#방배동맛집', 28),
#  ('#사당회식장소', 27),
#  ('#사당역술집', 27),
#  ('#서초맛집', 27),
#  ('#서초구맛집', 27),
#  ('#동작구맛집', 27),
#  ('#사당역족발', 26),
#  ('#사당족발', 26),
#  ('#맛집스타그램', 26),
#  ('#족발맛집', 26),
#  ('#사당맛집100족발', 26),
#  ('#100족발..', 17),
#  ('#사당맛집', 15),
#  ('#사당', 8),
#  ('#이수맛집', 6),
#  ('#맛스타그램', 6),
#  ('#사당역맛집', 5),
#  ('#맛스타그램', 4),
#  ('#방배맛집', 4),
#  ('#사당역', 4),
#  ('#일상', 4),
#  ('#맛집', 4),
#  ('#사당', 4),
#  ('#사당모임', 3)]

# %%
#막대차트 그려보기
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
import sys

if sys.platform in ['win32', 'win64']:
    font_name = 'malgun gothic'
elif sys.platform in ['darwin']:
    font_name = 'AppleGothic'
    
rc('font', family = font_name)

# %%
tag_counts_df = pd.DataFrame(tags_counts.most_common(30))
tag_counts_df.columns = ['tags', 'counts']

plt.figure(figsize = (10, 8))
sns.barplot(x='counts', y='tags', data=tag_counts_df)

# %%
#워드클라우드 라이브러리 불러오기
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import platform

if platform.system() == 'Windows':
    font_path = 'c:\\windows\\Fonts\\malgun.ttf'

# %%
wordcloud = WordCloud(font_path = font_path,
                     background_color = 'white',
                     max_words = 100,
                     relative_scaling = 0.3,
                     width = 800,
                     height = 400,).generate_from_frequencies(tags_counts)

plt.figure(figsize = (15, 10))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig("C:\\Users\\KIM EUNKI\\Google 드라이브\\GitHub\\Practice\\Insta_Sadang_WordCloud.png")
